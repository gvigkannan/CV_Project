# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import ndimage as ndi

from skimage import data
from skimage.util import img_as_float
from skimage.filters import gabor_kernel

import cv2

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
img = cv2.imread('1128.jpg')
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img)
plt.subplot(122)
plt.imshow(img_gray)

#Where summation fails!: 1309

# %% [markdown]
# plt.figure(figsize=(30,30))
# plt.subplot(121)
# #fig, (ax0, ax1, ax2) = plt.subplots(1,3, constrained_layout = True, figize = (10,10))
#
# g_kernel = cv2.getGaborKernel((15, 15), 8.0, np.pi/4, 10.0, 0.5, 0, ktype=cv2.CV_32F)
# h, w = g_kernel.shape[:2]
# filtered_img = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
# ax0.imshow(filtered_img)
# ax0.set_title("Kernel = 15")
#
# g_kernel = cv2.getGaborKernel((30, 30), 8.0, np.pi/4, 10.0, 0.5, 0, ktype=cv2.CV_32F)
# h, w = g_kernel.shape[:2]
# filtered_img = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
# ax1.imshow(filtered_img)
# ax1.set_title("Kernel = 30")
#
# g_kernel = cv2.getGaborKernel((60, 60), 8.0, np.pi/4, 10.0, 0.5, 0, ktype=cv2.CV_32F)
# h, w = g_kernel.shape[:2]
# filtered_img = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
# ax2.imshow(filtered_img)
# ax2.set_title("Kernel = 60")

# %%
plt.figure(figsize=(15,15))

#fig, (ax0, ax1, ax2) = plt.subplots(1,3, constrained_layout = True, figize = (10,10))
plt.subplot(421)
g_kernel = cv2.getGaborKernel((7, 7), 8.0, np.pi/4, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Color_Kernel = 7")

plt.subplot(423)
g_kernel = cv2.getGaborKernel((15, 15), 8.0, np.pi/4, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Color_Kernel = 15")

plt.subplot(425)
g_kernel = cv2.getGaborKernel((30, 30), 8.0, np.pi/4, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Color_Kernel = 30")

plt.subplot(427)
g_kernel = cv2.getGaborKernel((60, 60), 8.0, np.pi/4, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Color_Kernel = 60" )

plt.subplot(422)
g_kernel = cv2.getGaborKernel((7, 7), 8.0, np.pi/4, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img_gray, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Gray_Kernel = 7")

plt.subplot(424)
g_kernel = cv2.getGaborKernel((15, 15), 8.0, np.pi/4, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img_gray, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Gray_Kernel = 15")

plt.subplot(426)
g_kernel = cv2.getGaborKernel((30, 30), 8.0, np.pi/4, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img_gray, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Gray_Kernel = 30")

plt.subplot(428)
g_kernel = cv2.getGaborKernel((60, 60), 8.0, np.pi/4, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img_gray, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Gray_Kernel = 60" )
# Out:
# Text(0.5, 1.0, 'Gray_Kernel = 60')

# %% [markdown]
# Changing Sigma!

# %%
plt.figure(figsize=(10,10))

#Optimized
plt.subplot(321)
g_kernel = cv2.getGaborKernel((15, 15), 8, np.pi/4, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Sigma = 8" )

#Optimized
plt.subplot(323)
g_kernel = cv2.getGaborKernel((15, 15), 4, np.pi/4, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.imshow(filtered_img)
plt.title("Sigma = 4" )

#Changing Sigma!
plt.subplot(325)
g_kernel = cv2.getGaborKernel((15, 15), 16, np.pi/4, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.imshow(filtered_img)
plt.title("Sigma = 16" )


plt.subplot(322)
g_kernel = cv2.getGaborKernel((15, 15), 8, np.pi/4, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img_gray, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Gray_Sigma = 8" )

#Optimized
plt.subplot(324)
g_kernel = cv2.getGaborKernel((15, 15), 4, np.pi/4, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img_gray, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Gray_Sigma = 4" )

#Changing Sigma!
plt.subplot(326)
g_kernel = cv2.getGaborKernel((15, 15), 16, np.pi/4, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img_gray, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Gray_Sigma = 16" )
# Out:
# Text(0.5, 1.0, 'Gray_Sigma = 16')

# %%
#Thetha!

# %%
#Optimized
plt.figure(figsize=(15,15))
plt.subplot(331)
g_kernel = cv2.getGaborKernel((15, 15), 16, np.pi, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Theta = 180")

plt.subplot(332)
g_kernel = cv2.getGaborKernel((15, 15), 16, np.pi*2/3, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Theta = 120")

plt.subplot(333)
g_kernel = cv2.getGaborKernel((15, 15), 8.0, np.pi/2, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img_90 = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Theta = 90")

plt.subplot(334)
g_kernel = cv2.getGaborKernel((15, 15), 8.0, np.pi/3, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img_60 = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img_60)
plt.title("Theta = 60")

plt.subplot(335)
g_kernel = cv2.getGaborKernel((15, 15), 8.0, np.pi/4, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Theta = 45")

plt.subplot(336)
g_kernel = cv2.getGaborKernel((15, 15), 8.0, np.pi/6, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img_30 = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img_30)
plt.title("Theta = 30")

plt.subplot(337)
g_kernel = cv2.getGaborKernel((15, 15), 8.0, 0, 10.0, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img_0 = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Theta = 0")
# Out:
# Text(0.5, 1.0, 'Theta = 0')

# %%
#Boundaries are outlined pretty well!
new_img_filtered = filtered_img_30 + filtered_img_60
plt.imshow(new_img_filtered)
plt.title("30+60")
# Out:
# Text(0.5, 1.0, '30+60')

# %%
#Boundaries are outlined pretty well!
new_img_filtered = filtered_img_0 + filtered_img_90
plt.imshow(new_img_filtered)
plt.title("0+90")
# Out:
# Text(0.5, 1.0, '0+90')

# %% [markdown]
# Lambda!
# Wavelength of sinusoidal function

# %%
plt.figure(figsize=(10,10))
plt.subplot(321)
g_kernel = cv2.getGaborKernel((15, 15), 8.0, np.pi/4, 15, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Wavelength = 15")

plt.subplot(323)
g_kernel = cv2.getGaborKernel((15, 15), 8.0, np.pi/4, 5, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Wavelength = 5")

plt.subplot(325)
g_kernel = cv2.getGaborKernel((15, 15), 8.0, np.pi/4, 7, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Wavelength = 7")

plt.subplot(322)
g_kernel = cv2.getGaborKernel((15, 15), 8.0, np.pi/4, 15, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img_gray, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Wavelength = 15")

plt.subplot(324)
g_kernel = cv2.getGaborKernel((15, 15), 8.0, np.pi/4, 5, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img_gray, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Wavelength = 5")

plt.subplot(326)
g_kernel = cv2.getGaborKernel((15, 15), 8.0, np.pi/4, 7, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img_gray, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)
plt.title("Wavelength = 7")
#Brighness increases as the lambda value increases!
# Out:
# Text(0.5, 1.0, 'Wavelength = 7')

# %%
g_kernel = cv2.getGaborKernel((15, 15), 8.0, np.pi/4, 7, 0.5, 0, ktype=cv2.CV_32F)
h, w = g_kernel.shape[:2]
filtered_img = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)
plt.imshow(filtered_img)

# %%
img_nw = filtered_img /filtered_img.mean()
plt.imshow(img_nw)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
